# %% [markdown]
# # 05 — Giải thích Mô hình (Model Explainability)
#
# ## Mục tiêu
# Giải thích mô hình dự báo bằng ngôn ngữ kinh doanh — yêu cầu bắt buộc của đề thi (Phần 3).
#
# ## Nội dung
# - **SHAP values**: Waterfall plot, Beeswarm plot, Bar plot feature importance
# - **Partial Dependence Plots (PDP)**: ảnh hưởng của từng feature lên Revenue
# - **Business interpretation**: Giải thích bằng tiếng Việt cho từng feature quan trọng
#
# ## Ví dụ giải thích kinh doanh
# > "Feature `lag_7` (doanh thu 7 ngày trước) có SHAP importance cao nhất,
# > cho thấy doanh thu tuần này phụ thuộc mạnh vào doanh thu tuần trước —
# > gợi ý nên lập kế hoạch tồn kho theo chu kỳ 7 ngày."
#
# ## Output
# - `figures/shap_summary.png`
# - `docs/shap_analysis_summary.md` (cập nhật)
#
# ## Người phụ trách
# _(Điền tên thành viên)_

# %%
# TODO
import shap
import matplotlib.pyplot as plt
from pathlib import Path

FIGURES = Path('../figures')
